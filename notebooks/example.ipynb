# %%
import os
os.chdir('..')
print("Current Working Directory " , os.getcwd())
import sys
sys.path.append("../") # Add directory containing src/data to path
import numpy as np
import pandas as pd
from utils import *
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# Current Working Directory  /nfs/homedirs/zhz/uncertainty-quantification

# %%
train_label_path = '/lab/project-1/train_label.csv'
train_label = pd.read_csv(train_label_path)
label =[[] for i in range(4)]
for i in range(45280):
    if train_label.iloc[i].label == 'info':
        label[1].append(i)

# %%
# for i in label[0]:
#     if train_label.iloc[i].detail == 'tow-away-zone':
#         print (i)
#398
sign = np.load('/lab/project-1/train_signs/'+(train_label.iloc[398].sign_key)+'.npy')
detail = train_label.iloc[398].detail
plt.axis('off')
plt.title(detail)
plt.imshow(sign)

# %%
# for i in label[0]:
#     if train_label.iloc[i].detail == 'maximum-speed-limit-55':
#         print (i)
# 20: 299,381,579,4545 1354
# 55: 275, 507, 627, 1046, 2798
j=275
sign = np.load('/lab/project-1/train_signs/'+(train_label.iloc[j].sign_key)+'.npy')
detail = train_label.iloc[j].detail
plt.axis('off')
plt.title(detail)
plt.imshow(sign)

# %%
# for i in label[0]:
#     if train_label.iloc[i].detail == 'chevron-right-unsure':
#         print (i)
# 'chevron-right': 216, 314, 466, 532,45256
# 'chevron-right-unsure': 1571 2104 3442 6809 45127
j = 6809
sign = np.load('/lab/project-1/train_signs/'+(train_label.iloc[j].sign_key)+'.npy')
detail = train_label.iloc[j].detail
region = train_label.iloc[j].region
plt.axis('off')
plt.title(detail+'-'+region)
plt.imshow(sign)

# %%
sign = np.load('/lab/project-1/train_signs/'+(train_label.iloc[label[0][7591]].sign_key)+'.npy')
detail = train_label.iloc[label[0][7591]].detail
plt.axis('off')
plt.title(detail)
plt.imshow(sign)

# %%
sign = np.load('/lab/project-1/train_signs/'+(train_label.iloc[label[0][3]].sign_key)+'.npy')
detail = train_label.iloc[label[0][3]].detail
plt.axis('off')
plt.title(detail)
plt.imshow(sign)
